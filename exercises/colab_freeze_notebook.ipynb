# %% [markdown]
# # Freeze Tuning 真实模型实验
#
# 用 Qwen2-VL-2B 在 Colab T4 GPU 上跑完整的 Freeze Tuning 流程。
# 代码直接从 GitHub 加载。
#
# **运行前：** 菜单 → 运行时 → 更改运行时类型 → **T4 GPU**

# %%
# Cell 1: 安装依赖
# !pip install -q transformers accelerate torch Pillow qwen-vl-utils

# %%
# Cell 2: 从 GitHub 下载并运行实验代码
# !wget -q https://raw.githubusercontent.com/joannadengdeng/mmit/master/exercises/colab_cell2.py -O freeze_experiment.py
# !python freeze_experiment.py
