# %% [markdown]
# # mmit Colab Worker
#
# Run the cells below **once**. The worker will poll for jobs and execute them automatically.

# %%
# Cell 1: Clone repo + install deps
# !rm -rf /content/mmit
# !git clone https://github.com/joannadengdeng/mmit.git /content/mmit
# !pip install -q torch torchvision transformers peft accelerate bitsandbytes datasets pillow pyyaml

# Mount Drive for job queue
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/mmit_jobs /content/drive/MyDrive/mmit_results

# %%
# Cell 2: Start worker (runs forever — stop cell to quit)
import sys
sys.path.insert(0, '/content/mmit/src')

# Quick import test
import mmit
print(mmit.registry)
print('Import OK!\n')

# Run worker
# !PYTHONPATH=/content/mmit/src python /content/mmit/scripts/colab_worker.py
