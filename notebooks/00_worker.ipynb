# %% [markdown]
# # mmit Colab Worker
#
# Run the cells below **once**. The worker will poll Drive for jobs and execute them automatically.
#
# Your local Claude Code will write job files → Drive syncs → worker executes → results sync back.

# %%
# Cell 1: Setup
from google.colab import drive
drive.mount('/content/drive')

# !pip install -q torch torchvision transformers peft accelerate bitsandbytes datasets pillow pyyaml

# %%
# Cell 2: Start worker (runs forever — stop cell to quit)
# !python /content/drive/MyDrive/mmit/scripts/colab_worker.py
